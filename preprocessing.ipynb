# %%
import pandas as pd
import re

# %%
df = pd.read_csv('recipes.csv', index_col='RecipeId')
df = df[df['Description'].str.startswith('Make and share this') == False]
df = df.sample(n=100000)

# %%
df.head(5)
# Out:
#                                                        Name  AuthorId  \
# RecipeId
# 260527                             Bat Poop - for Halloween    297076
# 16512                                     Lemony Rice Pilaf     20371
# 443170    Sugar-Free Blueberry-Corn Muffins - Weight Wat...     57042
# 164010             Easy &amp; Quick Strawberry Wedding Cake     83060
# 215927                                 Vegetable Minestrone    461472
#
#            AuthorName CookTime PrepTime TotalTime         DatePublished  \
# RecipeId
# 260527        CandyTX    PT30M    PT20M     PT50M  2007-10-21T00:48:00Z
# 16512          Lennie    PT25M    PT10M     PT35M  2001-12-31T10:19:00Z
# 443170    internetnut    PT18M    PT15M     PT33M  2010-11-30T20:46:00Z
# 164010         KEHALI    PT35M    PT15M     PT50M  2006-04-12T16:43:00Z
# 215927     ladybug810    PT20M    PT40M      PT1H  2007-03-09T18:18:00Z
#
#                                                 Description  \
# RecipeId
# 260527    Tom came up with this for our son's Halloween-...
# 16512     This takes plain ol' rice to a new level. Goes...
# 443170    These fruity muffins get their sweetness from ...
# 164010    This is a variation of a cake served at my ste...
# 215927    This is my sister's recipe, but I have to shar...
#
#                                                      Images RecipeCategory  \
# RecipeId
# 260527    c("https://img.sndimg.com/food/image/upload/w_...          Candy
# 16512     c("https://img.sndimg.com/food/image/upload/w_...     White Rice
# 443170                                         character(0)          Beans
# 164010                                         character(0)        Dessert
# 215927    "https://img.sndimg.com/food/image/upload/w_55...     Clear Soup
#
#           ... SaturatedFatContent CholesterolContent SodiumContent  \
# RecipeId  ...
# 260527    ...                 8.8                6.3         550.4
# 16512     ...                 0.5                2.7         138.5
# 443170    ...                 0.5               29.2         120.1
# 164010    ...                 2.3                0.0         351.4
# 215927    ...                 2.4                2.4        1223.8
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 260527                   72.2           2.5          37.6             6.8
# 16512                    33.7           1.2           2.5             5.4
# 443170                   21.8           2.7           7.5             5.3
# 164010                   56.2           1.3          43.4             3.1
# 215927                   95.0          20.8          14.1            14.7
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 260527               NaN   30 squares
# 16512                8.0          NaN
# 443170              15.0   15 muffins
# 164010              12.0          NaN
# 215927               NaN     3 quarts
#
#                                          RecipeInstructions
# RecipeId
# 260527    c("Mash Pretzels till they are mostly crushed,...
# 16512     c("In a heavy saucepan, heat oil over mediumhe...
# 443170    c("Preheat the oven to 400. Line 15 muffin cup...
# 164010    c("Preheat oven to 350F and lightly grease/flo...
# 215927    c("Sauté the onion and garlic in olive oil ove...
#
# [5 rows x 27 columns]

# %%
def str_to_time(str_time):
    
    if pd.isnull(str_time):
        return None
    
    hours = re.findall('[0-9]*H', str_time)
    if hours:
        hours = int(hours[0][:-1])
    else:
        hours='00'
        
    minutes = re.findall('[0-9]*M', str_time)
    if minutes:
        minutes = minutes[0][:-1]
    else:
        minutes = '00'
        
    seconds = re.findall('[0-9]*S', str_time)
    if seconds:
        seconds = seconds[0][:-1]
    else:
        seconds='00'
        
    return f'{hours}:{minutes}:{seconds}'

# %%
timeCols = ['CookTime', 'PrepTime', 'TotalTime']
for col in timeCols:
    df[col] = df[col].apply(str_to_time)

# %%
def parse_instructions(instructions):
    if pd.isnull(instructions):
        return None
    instructions = instructions[3:len(instructions)-2]
    instructions = instructions.split("\", \"")
    instructions = '\n'.join(instructions)
    return instructions

# %%
df['RecipeInstructions'] = df['RecipeInstructions'].apply(parse_instructions)

# %%
def parse_ingredients(row):
    ingredients = row.RecipeIngredientParts
    ingredients = ingredients[3:len(ingredients)-2]
    ingredients = ingredients.split('\", \"')
    ingredients = [ingredient.title() for ingredient in ingredients]
    quantities = row.RecipeIngredientQuantities
    quantities = quantities[3:len(quantities)-2]
    quantities = quantities.split('\", \"')
    
    return dict(zip(ingredients, quantities))

# %%
df['Ingredients'] = [parse_ingredients(row) for row in df.itertuples(index=False)]

# %%
def recipe_yield_fix(quantity:str):
    if pd.isnull(quantity):
        return None
    return quantity.title()

df['RecipeYield'] = df['RecipeYield'].apply(recipe_yield_fix)

# %%
def keywords_fix(keywords: str):
    if pd.isnull(keywords):
        return None
    keywords = keywords[3:len(keywords)-2]
    keywords = keywords.split('\", \"')
    return keywords

df['Keywords'] = df['Keywords'].apply(keywords_fix)

# %%
cols_to_drop = ['AuthorId', 'AuthorName', 'DatePublished', 'Images', 'RecipeIngredientQuantities', 'RecipeIngredientParts', 'ReviewCount']
df = df.drop(columns=cols_to_drop)

# %%
df['ProteinPercentage'] = df['ProteinContent'] * 4 / df['Calories']
df['CarbohydratePercentage'] = df['CarbohydrateContent'] * 4 / df['Calories']
df['SugarPercentage'] = df['SugarContent'] * 4 / df['Calories']
df['FatPercentage'] = df['FatContent'] * 9 / df['Calories']

# %%
df.to_csv('recipes_final.csv', index=False)
